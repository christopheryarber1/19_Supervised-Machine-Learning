# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
#Check the files populate the Dataframe successfully
train_df.head()
#test_df.head()

#train_df.count()   # 12180 Records
#test_df.count()   # 4702 Records
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1    40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2    11000.0    0.2055       294.81           RENT     45000.0
# 3     4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4    14000.0    0.1797       505.93       MORTGAGE     43000.0
#
#   verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0        Not Verified          n  28.62          0.0             2.0  ...
# 1     Source Verified          n  11.72          2.0             0.0  ...
# 2            Verified          n  37.25          1.0             3.0  ...
# 3        Not Verified          n  42.89          1.0             0.0  ...
# 4     Source Verified          n  22.16          1.0             0.0  ...
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
# separate target feature for training data
y = train_df["target"]
target_names = ["low_risk", "high_risk"]

# %%
# Drop the label to create the X data
X = train_df.drop('target', axis=1)
X
# Out:
#        loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0         7000.0    0.1894       256.38       MORTGAGE     75000.0
# 1        40000.0    0.1614       975.71       MORTGAGE    102000.0
# 2        11000.0    0.2055       294.81           RENT     45000.0
# 3         4000.0    0.1612       140.87       MORTGAGE     38000.0
# 4        14000.0    0.1797       505.93       MORTGAGE     43000.0
# ...          ...       ...          ...            ...         ...
# 12175    19975.0    0.2565       801.09           RENT     28000.0
# 12176    15000.0    0.1774       540.34           RENT     50000.0
# 12177     3600.0    0.1862       131.28           RENT     60000.0
# 12178    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179    15000.0    0.1774       540.34           RENT     54080.0
#
#       verification_status pymnt_plan    dti  delinq_2yrs  inq_last_6mths  ...  \
# 0            Not Verified          n  28.62          0.0             2.0  ...
# ...

# %%
# Convert categorical data to numeric by 
# One-hot encoding the entire dataframe
X_dummies = pd.get_dummies(train_df)
print(X_dummies.columns)
X_dummies
# Out:
# Index(['loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
# Converting output labels to 0 and 1
y_label = LabelEncoder().fit_transform(train_df['target'])
y_label
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Convert categorical data to numeric and separate target feature for testing data
#ALREADY COMPLETED

# %%
# add missing dummy variables to testing set

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y_label, random_state=1)

from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(max_iter=40000)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=40000)

# %%
#Printing Model Score - Seems to break @ 100 moved to 20K then 40K.  This looks reasonable
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.7083743842364532
# Testing Data Score: 0.722495894909688

# %%
# Train a Random Forest Classifier model and print the model score - NOTE: Strange that this comes back at 1.0 for a score. 
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=1, n_estimators=50).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 1.0

# %%
# Scale the data - #NOTE: The results don't seem to change using either StandardScaler or MinMaxScaler
scaler = MinMaxScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score 
# CY NOTE: Strange that this comes back at 1.0 for a score. 
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier.fit(X_train_scaled, y_train)
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 1.0

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score 
# CY NOTE: Strange that this comes back at 1.0 for a score. 
clf = RandomForestClassifier(random_state=1, n_estimators=50).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 1.0

# %%
#This output looks incorrect, too. Top Left/Bottom Right should be relatively close. 
y_true = y_test
y_pred = classifier.predict(X_test)
confusion_matrix(y_true, y_pred)
# Out:
# array([[ 130, 1369],
#        [  61, 1485]], dtype=int64)

# %%
#This classifier looks correct - though it is highly accurate. 
y_true = y_test
y_pred = clf.predict(X_test)
confusion_matrix(y_true, y_pred)
# Out:
# array([[1499,    0],
#        [   0, 1546]], dtype=int64)

# %%
#LOGISTIC REGRESSION - This looks to be not so accurate. 
predictions = classifier.predict(X_test)
print(f"First 10 predictions:   {predictions[:10]}")
print(f"First 10 actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 predictions:   [1 1 1 1 1 1 0 1 1 1]
# First 10 actual labels: [0, 0, 1, 0, 0, 1, 0, 0, 1, 1]

# %%
#RANDOM FOREST - This looks on the money  for the first 10 records. 
predictions = clf.predict(X_test)
print(f"First 10 predictions:   {predictions[:10]}")
print(f"First 10 actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 predictions:   [0 0 1 0 0 1 0 0 1 1]
# First 10 actual labels: [0, 0, 1, 0, 0, 1, 0, 0, 1, 1]

# %%
# Predicted that Random Forest would do better, at the end that seems to be the case.
